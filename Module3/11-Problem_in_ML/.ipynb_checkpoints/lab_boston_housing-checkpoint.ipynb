# %% [markdown]
# # Understanding Over & Underfitting
# ## Predicting Boston Housing Prices

# %% [markdown]
# ## Getting Started
# In this project, you will use the Boston Housing Prices dataset to build several models to predict the prices of homes with particular qualities from the suburbs of Boston, MA.
# We will build models with several different parameters, which will change the goodness of fit for each.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
# ## Data Exploration
# Since we want to predict the value of houses, the **target variable**, `'MEDV'`, will be the variable we seek to predict.

# %% [markdown]
# ### Import and explore the data. Clean the data for outliers and missing values.

# %%
data = pd.read_csv(r"C:\Users\Shinemet\Ironhack\Labs\Module3\11. Problem_in_ML\boston_data.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873  4.0  305.0
# 1  0.10328  25.0   5.13   0.0  0.453  5.927  47.2  6.9320  8.0  284.0
# 2  0.34940   0.0   9.90   0.0  0.544  5.972  76.7  3.1025  4.0  304.0
# 3  2.73397   0.0  19.58   0.0  0.871  5.597  94.9  1.5257  5.0  403.0
# 4  0.04337  21.0   5.64   0.0  0.439  6.115  63.0  6.8147  4.0  243.0
#
#    ptratio   black  lstat  medv
# 0     19.2  376.94   9.88  21.7
# 1     19.7  396.90   9.22  19.6
# 2     18.4  396.24   9.97  20.3
# 3     14.7  351.85  21.45  15.4
# 4     16.8  393.97   9.43  20.5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     404 non-null    float64
#  1   zn       404 non-null    float64
#  2   indus    404 non-null    float64
#  3   chas     404 non-null    float64
#  4   nox      404 non-null    float64
#  5   rm       404 non-null    float64
#  6   age      404 non-null    float64
#  7   dis      404 non-null    float64
#  8   rad      404 non-null    float64
#  9   tax      404 non-null    float64
#  10  ptratio  404 non-null    float64
#  11  black    404 non-null    float64
#  12  lstat    404 non-null    float64
#  13  medv     404 non-null    float64
# dtypes: float64(14)
# memory usage: 44.3 KB

# %%
data.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# *No missing values and no remarkable outliers for this dataset. We can explore further with EDA.*

# %% [markdown]
# ### Next, we want to explore the data. Pick several varibables you think will be ost correlated with the prices of homes in Boston, and create plots that show the data dispersion as well as the regression line of best fit.

# %%
# check correlations and plot them
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, square=True)
# Out:
# <AxesSubplot:>

# %%
# rm and lstat have moderate collinearity with target variable, let's plot them
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

sns.regplot(data.rm, data.medv, ax=ax1)
sns.regplot(data.lstat, data.medv, ax=ax2)

plt.show()
# Out:
# C:\Users\Shinemet\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Shinemet\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 3 other features seem to have a collinearity with target variable, let's plot them: no strong correlation
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

ax1.scatter(data.indus, data.medv, c='g')
ax2.scatter(data.tax, data.medv, c='g')
ax3.scatter(data.ptratio, data.medv, c='g')

plt.show()

# %% [markdown]
# ### What do these plots tell you about the relationships between these variables and the prices of homes in Boston? Are these the relationships you expected to see in these variables?

# %% [markdown]
# *2 features have high correlation with target variable: rm is positively correlated to price of homes and lstat has strong linear and negative correlation with price of homes.*

# %% [markdown]
# ### Make a heatmap of the remaining variables. Are there any variables that you did not consider that have very high correlations? What are they?

# %%
# I would have expected criminality to have a much higher correlation with prices
plt.scatter(data.crim, data.medv)

# %%
# also age
plt.scatter(data.age, data.medv)

# %% [markdown]
# ### Calculate Statistics
# Calculate descriptive statistics for housing price. Include the minimum, maximum, mean, median, and standard deviation.

# %%
# stats
data.describe()
# Out:
#              crim          zn       indus        chas         nox         rm  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.00000
# mean     3.730912   10.509901   11.189901    0.069307    0.556710    6.30145
# std      8.943922   22.053733    6.814909    0.254290    0.117321    0.67583
# min      0.006320    0.000000    0.460000    0.000000    0.392000    3.56100
# 25%      0.082382    0.000000    5.190000    0.000000    0.453000    5.90275
# 50%      0.253715    0.000000    9.795000    0.000000    0.538000    6.23050
# 75%      4.053158   12.500000   18.100000    0.000000    0.631000    6.62925
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.78000
#
#               age         dis         rad         tax     ptratio       black  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.601733    3.799666    9.836634  411.688119   18.444554  355.068243
# ...

# %% [markdown]
# ----
#
# ## Developing a Model

# %% [markdown]
# ### Implementation: Define a Performance Metric
# What is the performance meteric with which you will determine the performance of your model? Create a function that calculates this performance metric, and then returns the score.

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    score = r2_score(y_true, y_predict)
    print('R-squared score: %.3f' % score)

# %% [markdown]
# ### Implementation: Shuffle and Split Data
# Split the data into the testing and training datasets. Shuffle the data as well to remove any bias in selecting the traing and test.

# %%
# test-train split dataset
from sklearn.model_selection import train_test_split

X = data.drop('medv', axis=1)
y = data.medv

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=0)
print(X.shape, y.shape)
# Out:
# (404, 13) (404,)

# %% [markdown]
# ----
#
# ## Analyzing Model Performance
# Next, we are going to build a Random Forest Regressor, and test its performance with several different parameter settings.

# %% [markdown]
# ### Learning Curves
# Lets build the different models. Set the max_depth parameter to 2, 4, 6, 8, and 10 respectively.

# %%
# Five separate RFR here with the given max depths
from sklearn.ensemble import RandomForestRegressor

depth = [2, 4, 6, 8, 10]

for i in depth:
    rfr = RandomForestRegressor(max_depth=i, random_state=0)
    rfr.fit(X_train, y_train)
    print(rfr)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)
# RandomForestRegressor(max_depth=4, random_state=0)
# RandomForestRegressor(max_depth=6, random_state=0)
# RandomForestRegressor(max_depth=8, random_state=0)
# RandomForestRegressor(max_depth=10, random_state=0)

# %% [markdown]
# Now, plot the score for each tree on the training set and on the testing set.

# %%
# Produce a plot with the score for the testing and training for the different max depths
for i in depth:
    rfr = RandomForestRegressor(max_depth=i, random_state=0)
    rfr.fit(X_train, y_train)
    y_pred = rfr.predict(X_test)
    print(performance_metric(y_test, y_pred))
# Out:
# R-squared score: 0.802
# None
# R-squared score: 0.872
# None
# R-squared score: 0.902
# None
# R-squared score: 0.909
# None
# R-squared score: 0.910
# None

# %% [markdown]
# What do these results tell you about the effect of the depth of the trees on the performance of the model?

# %% [markdown]
# *The more the depth, the better the score.*

# %% [markdown]
# ### Bias-Variance Tradeoff
# When the model is trained with a maximum depth of 1, does the model suffer from high bias or from high variance? How about when the model is trained with a maximum depth of 10?

# %%
# let's compute our score function with both depth:
for i in [1, 11]:
    rfr = RandomForestRegressor(max_depth=i, random_state=0)
    rfr.fit(X_train, y_train)
    y_pred = rfr.predict(X_test)
    print(performance_metric(y_test, y_pred))
# Out:
# R-squared score: 0.607
# None
# R-squared score: 0.910
# None

# %% [markdown]
# *With a max depth of 1, the score is very low: there is high bias and low variance.
# With a max depth of 10, the score is high: there is low bias and high variance.*

# %% [markdown]
# ### Best-Guess Optimal Model
# What is the max_depth parameter that you think would optimize the model? Run your model and explain its performance.

# %%
# loop to find the optimized parameters of this model: 

for i in range(1, 30, 5):
    rfr = RandomForestRegressor(max_depth=i, random_state=0)
    rfr.fit(X_train, y_train)
    y_pred = rfr.predict(X_test)
    print(performance_metric(y_test, y_pred))
# Out:
# R-squared score: 0.607
# None
# R-squared score: 0.902
# None
# R-squared score: 0.910
# None
# R-squared score: 0.911
# None
# R-squared score: 0.911
# None
# R-squared score: 0.911
# None

# %% [markdown]
# *A maximum score is reached with max_depth=20: further, the branches of the trees are getting too close to the datapoints.*

# %% [markdown]
# ### Applicability
# *In a few sentences, discuss whether the constructed model should or should not be used in a real-world setting.*
# **Hint:** Some questions to answering:
# - *How relevant today is data that was collected from 1978?*
# - *Are the features present in the data sufficient to describe a home?*
# - *Is the model robust enough to make consistent predictions?*
# - *Would data collected in an urban city like Boston be applicable in a rural city?*

# %% [markdown]
# - The dataset is probably too old to apply to our analysis, because we use context to formulate assumptions
# - The features are probably not enough in quality and quantity (some are even shocking, like the presence of Afro-Americans to explain the prices)
# - The model seems robust to make predictions, but it is based on a small number of features
# - Again, model results are to be put in the context of the dataset understanding: they would not apply to a rural city
